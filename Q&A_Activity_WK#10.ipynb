# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the data into python

# %%
data=pd.read_csv('E:\Python programming\Wk#10\week10.csv')

# %%
data
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.41744     8.059332  356.886136
# 1      9.092223  181.101509  17978.98634     6.546600  310.135738
# 2      5.584087  188.313324  28748.68774     7.544869  326.678363
# 3     10.223862  248.071735  28749.71654     7.513408  393.663395
# 4      8.635849  203.361523  13672.09176     4.563009  303.309771
# ...         ...         ...          ...          ...         ...
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       363.266516       18.436525       100.341674   4.628771
# ...

# %% [markdown]
# # 2. Check for null values

# %%
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# No null value in the data set

# %% [markdown]
# # 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations

# %%
fg=data[['Hardness','Sulfate','Organic_carbon']]
fg.hist(figsize=(20,15),color='green')
plt.show()

# %% [markdown]
# All the variable data points follows normal distribution

# %% [markdown]
# # 4. Carry out correlation analysis on the dataset

# %%
correl= data.corr()
plt.subplots(figsize=(15,6))
sns.heatmap(correl,vmin = -0.04, vmax = 0.2,annot = True,linewidth=.2,cmap = "viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # a.  find the correlation factor between ph and Chloramines

# %%
data1= data[['ph','Chloramines']]
corr1= data1.corr()
corr1
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %% [markdown]
# # b. find the correlation factor between ph and Conductivity

# %%
data2= data[['ph','Conductivity']]
corr2= data2.corr()
corr2
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %% [markdown]
# Inference:
#     Both having a correlation coeffient near to zero and hence we can conclude that there is a very weak correlation between "ph and Chloramines" and "pH and conductivity".
